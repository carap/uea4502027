# %% [markdown]
# # Test02 - Linear regression
#
# Dado el conjunto de pares ordenados $\mathcal{D} = \{(−1, −2), (1, 1), (2, 5)\}$ encuentre los valores de $\beta_0$  y $\beta_1$, que mejor se ajusten a los puntos en $\mathcal{D}$, los siguientes modelos:
# + $f(x) = \beta_0 + \beta_1 x$
# + $g(x) = \beta_0 x + \beta_1 x^2$,
#
# Compare el **error cuadrático** $\lVert e \rVert ^ 2$, asociado a cada función y concluya al respecto.

# %%
# Out:
# beta1 =  2.21428571429
# beta0 =  -0.142857142857
#  e² =  [ 1.78571429]

# %%
# Out:
# beta1 =  0.227272727273
# beta0 =  1.86363636364
#  e² =  [ 1.45454545]
